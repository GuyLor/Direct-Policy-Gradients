# %% [markdown]
# # RL Windy cliff walking top-down construction and direct optimization

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import hsv_to_rgb
import time

# %%
def timing(f):
    def wrap(*args, **kw):
        time1 = time.time()
        ret = f(*args, **kw)
        time2 = time.time()
        print '%s function took %0.3f ms' % (f.func_name, (time2-time1)*1000.0)
        return ret
    return wrap

# %% [markdown]
# ##  Environment

# %%
height = 4 #2*num_steps+1
width = 8 #2*num_steps+1
start = (height-1,0)#(num_steps,num_steps)
obj = (height-1,width-1)#(num_steps,2*num_steps-2)

num_states = width * height
solution_length = width+1

# %%
UP = 0
DOWN = 1
RIGHT = 2
LEFT = 3

ACTIONS = ['UP', 'DOWN', 'RIGHT', 'LEFT']
num_actions = len(ACTIONS)

wind = [0 for _ in range(width)] # probability of being pushed down at column i 
# for now, without wind 
#wind[2],wind[3] = 0.2,0.2

# %%
class GridWorld:
    terrain_color = dict(normal=[127.0/360, 0.0, 96.0/100],
                         corridor=[80.0/360, 25.0/100, 96.0/100],
                         objective=[26.0/360, 100.0/100, 100.0/100],
                         cliff=[247.0/360, 92.0/100, 70.0/100],
                         player=[344.0/360, 93.0/100, 100.0/100])        
    def __init__(self):
        self.player = None
        self._create_grid()  
        self._draw_grid()
        
    def _create_grid(self, initial_grid=None):
        self.grid = self.terrain_color['normal'] * np.ones((height, width, 3))
        self._add_objectives(self.grid)
        
    def _add_objectives(self, grid,history = None):
        grid[start[0], start[1]:obj[1]] = self.terrain_color['cliff']
        
        grid[start[0]-2, start[1]:obj[1]+1] = self.terrain_color['corridor']
        grid[start[0]-1,start[1]] = self.terrain_color['corridor']
        grid[start[0]-1,obj[1]] = self.terrain_color['corridor']
        
        grid[obj] = self.terrain_color['objective']
        grid[start] = self.terrain_color['player']
        if history is not None:
            for idx in history:
                grid[self._id_to_position(idx)] = self.terrain_color['player']
    def _draw_grid(self):
        self.fig, self.ax = plt.subplots(figsize=(width, height))
        self.ax.grid(which='minor')
        self.q_texts = [self.ax.text(*self._id_to_position(i)[::-1], s='0',
                                     fontsize=11, verticalalignment='center', 
                                     horizontalalignment='center') for i in range(height * width)]  
         
        self.im = self.ax.imshow(hsv_to_rgb(self.grid), cmap='terrain',
                                 interpolation='nearest', vmin=0, vmax=1)        
        self.ax.set_xticks(np.arange(width))
        self.ax.set_xticks(np.arange(width) - 0.5, minor=True)
        self.ax.set_yticks(np.arange(height))
        self.ax.set_yticks(np.arange(height) - 0.5, minor=True)
        
    def reset(self):
        self.player = start      
        return self._position_to_id(self.player)
    
    def step(self,state, action):
        # Possible actions
        
        state = self._id_to_position(state)
        if action == 0 and state[0] > 0:
            state = (state[0] - 1, state[1])
        if action == 1 and state[0] < height - 1:
            state = (state[0] + 1, state[1])
        if action == 2 and state[1] < width - 1:
            state = (state[0], state[1] + 1)
        if action == 3 and state[1] > 0:
            state = (state[0], state[1] - 1)
        """    
        if action == 4:
            state = state
        """
        failed = all(self.grid[state] == self.terrain_color['cliff'])
        succeeded = all(self.grid[state] == self.terrain_color['objective'])
        corridor = all(self.grid[state] == self.terrain_color['corridor'])
        
        if not (failed or succeeded):
            state = self._add_wind(state)
        
        # the wind can change his destiny :)
        failed = all(self.grid[state] == self.terrain_color['cliff'])
        succeeded = all(self.grid[state] == self.terrain_color['objective'])
        corridor = all(self.grid[state] == self.terrain_color['corridor'])
        # Rules
        if failed:
            reward = -100
            status = 'failed'
        elif succeeded:
            reward = 100
            status = 'succeeded'
        elif corridor:
            reward = -1
            status = 'walking'            
        else:
            reward = -1
            status = 'walking'
            
        return self._position_to_id(state), reward, status
    
    def _add_wind(self,new_state):
        
        x_loc = new_state[1]
        p = np.random.random()
        if p<wind[x_loc] and new_state[0] < height-1:
            new_state = (new_state[0]+1, new_state[1])
        return new_state
            
    def _position_to_id(self, pos):
        ''' Maps a position in x,y coordinates to a unique ID '''
        return pos[0] * width + pos[1]
    
    def _id_to_position(self, idx):
        return (idx // width), (idx % width)
        
    def render(self, q_values=None, action=None,history = None, max_q=False, colorize_q=False):
        assert self.player is not None, 'You first need to call .reset()'  
        def change_range(values, vmin=0, vmax=1):
            start_zero = values - np.min(values)
            return (start_zero / (np.max(start_zero) + 1e-7)) * (vmax - vmin) + vmin 
        
        if colorize_q:
            assert q_values is not None, 'q_values must not be None for using colorize_q'            
            grid = self.terrain_color['normal'] * np.ones((height, width, 3))
            values = change_range(np.max(q_values, -1)).reshape(height, width)
            grid[:, :, 1] = values
            self._add_objectives(grid,history)
        else:            
            grid = self.grid.copy()
            
        grid[self.player] = self.terrain_color['player']       
        self.im.set_data(hsv_to_rgb(grid))
               
        if q_values is not None:
            xs = np.repeat(np.arange(width), height)
            ys = np.tile(np.arange(height), width)  
            
            for i, text in enumerate(self.q_texts):
                if max_q:
                    q = max(q_values[i])    
                    txt = '{:.2f}'.format(q)
                    text.set_text(txt)
                else:                
                    actions = ['U', 'D', 'R', 'L']
                    txt = '\n'.join(['{}: {:.2f}'.format(k, q) for k, q in zip(actions, q_values[i])])
                    text.set_text(txt)

# %%
env = GridWorld()

# %% [markdown]
# ## Policy model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical
import collections
import random

# %%
class Policy(nn.Module):
    def __init__(self):
        super(Policy, self).__init__()       
        
        self.fc1 = nn.Linear(num_states,num_actions)
        
    def forward(self,state):
        #print state.size()
        state = torch.FloatTensor(state.size(0),num_states).zero_().scatter_(-1, state,1.0) # convert idx to 'one-hot'
        logits = self.fc1(state)
        
        return logits       

policy = Policy()

# %% [markdown]
# ## Top-down construction

# %%
def sample_gumbel(mu):
    """Sample a Gumbel(mu)."""    
    return -np.log(np.random.exponential()) + mu


def sample_truncated_gumbel(mu, b):
    """Sample a Gumbel(mu) truncated to be less than b."""    
    return -np.log(np.random.exponential() + np.exp(-b + mu)) + mu

  
def sample_gumbel_argmax(logits):
    """Sample from a softmax distribution over logits.

    TODO: check this is correct.

    Args:
    logits: A flat numpy array of logits.

    Returns:
    A sample from softmax(logits).
    """
    return np.argmax(-np.log(np.random.exponential(size=logits.shape)) + logits)


def logsumexp(logits):
    c = np.max(logits)
    return np.log(np.sum(np.exp(logits - c))) + c


def log_softmax(logits, axis=1):
    """Normalize logits per row so that they are logprobs.
  
      TODO: check this is correct. 
    """
    maxes = np.max(logits, axis=axis, keepdims=True)
    offset_logits = logits - maxes
    log_zs = np.log(np.sum(np.exp(offset_logits), axis=axis, keepdims=True))
    return offset_logits - log_zs

# %%
# Make a node without a state, and also don't allow `next_actions` to be None.
# Just put in all possible next actions when the node is created.
Node = collections.namedtuple('Node', 
                              [
                                  'prefix',
                                  'states',
                                  'reward_so_far',
                                  'status',                                  
                                  'logprob_so_far',
                                  'max_gumbel', 
                                  'next_actions',
                                  
                              ])

# Namedtuple for storing results
Trajectory = collections.namedtuple('Trajectory', ['actions','states','gumbel','reward','status','node'])

# %%
def sample_trajectory_section_gumbels(policy_model,init_node,num_actions,section_length ,epsilon=1.0):
    """Samples an independent Gumbel(logprob) for each trajectory in top-down-ish order.

    Args:
        policy_model: Pytorch model that gets state and returns actions logits
        num_actions: Number of possible actions, should be equal to the policy output size
        max_length: Maximum length of a trajectory to allow.
        epsilon: direct optimization parameter
    Returns:
        y_opt: trajectory of max gumbel 
        y_direct: trajectory of max gumbel + reward*epsilon (target)
        final_trajectories: int, number of all trajectories (can be deleted, just for debugging)
    """

    # Start with a node for all trajectories.    
    root_node = init_node
    #init_node_prefix_length = len(root_node.prefix)
    queue = [root_node]
    max_gumbel_eps_reward ,max_gumbel= -float('Inf'),-float('Inf')
    final_trajectories = []
    
    while queue:
        parent = queue.pop()
        if  len(parent.prefix) - len(root_node.prefix) == section_length or parent.status in ['failed','succeeded']:
            t = Trajectory(actions=parent.prefix,
                           states=parent.states,
                           gumbel=parent.max_gumbel,
                           reward=parent.reward_so_far,
                           status=parent.status,
                           node = parent)

            assert len(t.actions) == len(parent.states)-1
            final_trajectories.append(t)
            #computations for direct optimization
            gumbel_eps_reward = t.gumbel + epsilon*t.reward
            if gumbel_eps_reward > max_gumbel_eps_reward:
                max_gumbel_eps_reward = gumbel_eps_reward
                t_direct = t

            t_opt = t
            continue

        current_state = parent.states[-1]       
        
        with torch.no_grad():
            state = torch.LongTensor([current_state]).unsqueeze(0)
            action_logprobs = policy_model(state).numpy().squeeze(0)
        
        next_action_logprobs = action_logprobs[parent.next_actions]
        special_action_index = sample_gumbel_argmax(next_action_logprobs)
        special_action = parent.next_actions[special_action_index]
        special_action_logprob = action_logprobs[special_action]
        

        new_state,reward,status = env.step(current_state,special_action)

        special_child = Node(prefix=parent.prefix + [special_action],
                             states=parent.states + [new_state],
                             reward_so_far=parent.reward_so_far + reward,
                             status=status,
                             logprob_so_far=parent.logprob_so_far + special_action_logprob,
                             max_gumbel=parent.max_gumbel, 
                             next_actions=range(num_actions)) # All next actions are possible.

        queue.append(special_child)

        # Sample the max gumbel for the non-chosen actions and create an "other
        # children" node if there are any alternatives left.

        other_actions = [i for i in parent.next_actions if i != special_action]
        assert len(other_actions) == len(parent.next_actions) - 1

        if other_actions:
            other_max_location = logsumexp(action_logprobs[other_actions])
            other_max_gumbel = sample_truncated_gumbel(parent.logprob_so_far + other_max_location, 
                                                     parent.max_gumbel)
            other_children = Node(prefix=parent.prefix,
                                states=parent.states,
                                reward_so_far=parent.reward_so_far,
                                status=parent.status,
                                logprob_so_far=parent.logprob_so_far,
                                max_gumbel=other_max_gumbel,
                                next_actions=other_actions)



            queue.append(other_children)          

    return t_opt, t_direct,final_trajectories #  final_trajectories is

def sample_full_trajectory_gumbels(policy_model,num_actions,section_length=3,epsilon=1.0):
    root_node = Node(prefix=[],
       states = [env.reset()],
       reward_so_far=0,
       status='walking',  
       logprob_so_far=0,
       max_gumbel=sample_gumbel(0), 
       next_actions=range(num_actions))
    current_node = root_node
    while current_node.status not in ['failed','succeeded']:
        #section_length = random.choice(range(3,5))
        t_opt, t_direct,final_trajectories = sample_trajectory_section_gumbels(policy_model=policy_model,
                                                                       init_node = current_node,
                                                                       num_actions=num_actions,
                                                                       section_length=section_length,
                                                                       epsilon=epsilon)
        current_node = t_opt.node
    return t_opt, t_direct,final_trajectories

# %%
#policy = Policy()
t_opt, t_direct,final_trajectories = sample_full_trajectory_gumbels(policy,num_actions)
actions = t_opt.actions
print len(final_trajectories)
for t in final_trajectories:
    print t, "\n"
print [ACTIONS[actions[i]] for i in range(len(actions))]
# Out:
# 64
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 2, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 1, 9], gumbel=-2.775701311584161, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 2, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 1, 9], reward_so_far=-21, status='walking', logprob_so_far=-1.1359646394848824, max_gumbel=-2.775701311584161, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 2, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 1, 1], gumbel=-2.6379400894204927, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 2, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 1, 1], reward_so_far=-21, status='walking', logprob_so_far=-1.2708024308085442, max_gumbel=-2.6379400894204927, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 2, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 1, 0], gumbel=-2.4520312630259475, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 2, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 1, 0], reward_so_far=-21, status='walking', logprob_so_far=-1.1645234748721123, max_gumbel=-2.4520312630259475, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 2, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 1, 2], gumbel=-2.427869800361923, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 2, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 1, 2], reward_so_far=-21, status='walking', logprob_so_far=-1.4055563285946846, max_gumbel=-2.427869800361923, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 3, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 0, 1], gumbel=-2.637111046475174, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 3, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 0, 1], reward_so_far=-21, status='walking', logprob_so_far=-1.3680330142378807, max_gumbel=-2.637111046475174, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 3, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 0, 0], gumbel=-2.610757896328121, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 3, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 0, 0], reward_so_far=-21, status='walking', logprob_so_far=-1.5466460511088371, max_gumbel=-2.610757896328121, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 3, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 0, 8], gumbel=-2.4045812387246936, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 3, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 0, 8], reward_so_far=-21, status='walking', logprob_so_far=-1.5563523396849632, max_gumbel=-2.4045812387246936, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 3, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 0, 0], gumbel=-2.242477355653884, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 3, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 0, 0], reward_so_far=-21, status='walking', logprob_so_far=-1.351858489215374, max_gumbel=-2.242477355653884, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 0, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 0, 0], gumbel=-2.5719785914751494, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 0, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 0, 0], reward_so_far=-21, status='walking', logprob_so_far=-1.351858489215374, max_gumbel=-2.5719785914751494, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 0, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 0, 8], gumbel=-2.334370897994196, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 0, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 0, 8], reward_so_far=-21, status='walking', logprob_so_far=-1.3615647777915, max_gumbel=-2.334370897994196, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 0, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 0, 0], gumbel=-2.3339265616031266, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 0, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 0, 0], reward_so_far=-21, status='walking', logprob_so_far=-1.1570709273219109, max_gumbel=-2.3339265616031266, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 0, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 0, 1], gumbel=-2.199709514798051, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 0, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 0, 1], reward_so_far=-21, status='walking', logprob_so_far=-1.1732454523444176, max_gumbel=-2.199709514798051, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 1, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 8, 16], gumbel=-2.756149123754417, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 1, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 8, 16], reward_so_far=-21, status='walking', logprob_so_far=-1.5678046867251396, max_gumbel=-2.756149123754417, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 1, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 8, 9], gumbel=-2.7380420806337575, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 1, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 8, 9], reward_so_far=-21, status='walking', logprob_so_far=-1.5117340460419655, max_gumbel=-2.7380420806337575, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 1, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 8, 8], gumbel=-2.5142971815942, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 1, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 8, 8], reward_so_far=-21, status='walking', logprob_so_far=-1.3795863911509514, max_gumbel=-2.5142971815942, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 1, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 8, 0], gumbel=-2.0762011646295173, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 0, 1, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 0, 8, 0], reward_so_far=-21, status='walking', logprob_so_far=-1.4168918058276176, max_gumbel=-2.0762011646295173, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 2, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 9, 17], gumbel=-2.112068481459415, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 2, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 9, 17], reward_so_far=-21, status='walking', logprob_so_far=-1.345539890229702, max_gumbel=-2.112068481459415, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 2, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 9, 1], gumbel=-2.1102503964623827, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 2, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 9, 1], reward_so_far=-21, status='walking', logprob_so_far=-1.254832185804844, max_gumbel=-2.1102503964623827, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 2, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 9, 8], gumbel=-2.0357820030248956, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 2, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 9, 8], reward_so_far=-21, status='walking', logprob_so_far=-1.5332598313689232, max_gumbel=-2.0357820030248956, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 2, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 9, 10], gumbel=-2.019270011626551, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 2, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 9, 10], reward_so_far=-21, status='walking', logprob_so_far=-1.5061271712183952, max_gumbel=-2.019270011626551, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 0, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 0, 8], gumbel=-2.0969455521085996, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 0, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 0, 8], reward_so_far=-21, status='walking', logprob_so_far=-1.3795863911509514, max_gumbel=-2.0969455521085996, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 0, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 0, 0], gumbel=-1.4831082640861037, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 0, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 0, 0], reward_so_far=-21, status='walking', logprob_so_far=-1.1750925406813622, max_gumbel=-1.4831082640861037, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 0, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 0, 1], gumbel=-1.3911512387653353, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 0, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 0, 1], reward_so_far=-21, status='walking', logprob_so_far=-1.1912670657038689, max_gumbel=-1.3911512387653353, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 0, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 0, 0], gumbel=-1.2895578737937954, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 0, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 0, 0], reward_so_far=-21, status='walking', logprob_so_far=-1.3698801025748253, max_gumbel=-1.2895578737937954, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 1, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 16, 24], gumbel=-1.5276824669445193, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 1, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 16, 24], reward_so_far=-21, status='walking', logprob_so_far=-1.3477202877402306, max_gumbel=-1.5276824669445193, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 1, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 16, 17], gumbel=-1.3940308495589973, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 1, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 16, 17], reward_so_far=-21, status='walking', logprob_so_far=-1.349092148244381, max_gumbel=-1.3940308495589973, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 1, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 16, 16], gumbel=-0.822186522787496, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 1, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 16, 16], reward_so_far=-21, status='walking', logprob_so_far=-1.3079681620001793, max_gumbel=-0.822186522787496, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 1, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 16, 8], gumbel=-0.6915158160246875, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 1, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 16, 8], reward_so_far=-21, status='walking', logprob_so_far=-1.6295474842190742, max_gumbel=-0.6915158160246875, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 3, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 8, 16], gumbel=-2.138965677319446, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 3, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 8, 16], reward_so_far=-21, status='walking', logprob_so_far=-1.3440270349383354, max_gumbel=-2.138965677319446, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 3, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 8, 0], gumbel=-1.4632893553264932, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 3, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 8, 0], reward_so_far=-21, status='walking', logprob_so_far=-1.1931141540408134, max_gumbel=-1.4632893553264932, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 3, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 8, 8], gumbel=-0.522800157882636, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 3, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 8, 8], reward_so_far=-21, status='walking', logprob_so_far=-1.1558087393641472, max_gumbel=-0.522800157882636, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 3, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 8, 9], gumbel=-0.35053569782317506, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 3, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 8, 8, 9], reward_so_far=-21, status='walking', logprob_so_far=-1.2879563942551613, max_gumbel=-0.35053569782317506, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 3, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 8, 9], gumbel=-3.1221778526533805, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 3, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 8, 9], reward_so_far=-21, status='walking', logprob_so_far=-1.6654074862599373, max_gumbel=-3.1221778526533805, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 3, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 8, 0], gumbel=-1.8406433760819052, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 3, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 8, 0], reward_so_far=-21, status='walking', logprob_so_far=-1.5705652460455894, max_gumbel=-1.8406433760819052, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 3, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 8, 16], gumbel=-1.6932718139224994, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 3, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 8, 16], reward_so_far=-21, status='walking', logprob_so_far=-1.7214781269431114, max_gumbel=-1.6932718139224994, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 3, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 8, 8], gumbel=-1.499649565278798, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 3, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 8, 8], reward_so_far=-21, status='walking', logprob_so_far=-1.5332598313689232, max_gumbel=-1.499649565278798, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 2, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 10, 2], gumbel=-1.8848266170276635, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 2, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 10, 2], reward_so_far=-21, status='walking', logprob_so_far=-1.5705281272530556, max_gumbel=-1.8848266170276635, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 2, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 10, 9], gumbel=-1.8466586539507577, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 2, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 10, 9], reward_so_far=-21, status='walking', logprob_so_far=-1.7174062207341194, max_gumbel=-1.8466586539507577, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 2, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 10, 18], gumbel=-1.4441018611888152, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 2, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 10, 18], reward_so_far=-21, status='walking', logprob_so_far=-1.5733058080077171, max_gumbel=-1.4441018611888152, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 2, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 10, 11], gumbel=-1.0764241309786275, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 2, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 10, 11], reward_so_far=-21, status='walking', logprob_so_far=-1.660800613462925, max_gumbel=-1.0764241309786275, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 1, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 17, 18], gumbel=-2.2262344681948685, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 1, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 17, 18], reward_so_far=-21, status='walking', logprob_so_far=-1.4975941553711891, max_gumbel=-2.2262344681948685, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 1, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 17, 16], gumbel=-1.0689959877339565, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 1, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 17, 16], reward_so_far=-21, status='walking', logprob_so_far=-1.452941544353962, max_gumbel=-1.0689959877339565, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 1, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 17, 9], gumbel=-0.4335840297330289, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 1, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 17, 9], reward_so_far=-21, status='walking', logprob_so_far=-1.5971296653151512, max_gumbel=-0.4335840297330289, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 1, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 17, 25], gumbel=0.7086646511304027, reward=-120, status='failed', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 1, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 17, 25], reward_so_far=-120, status='failed', logprob_so_far=-1.3028105273842812, max_gumbel=0.7086646511304027, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 0, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 1, 0], gumbel=-2.0750350008719884, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 0, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 1, 0], reward_so_far=-21, status='walking', logprob_so_far=-1.2280885949730873, max_gumbel=-2.0750350008719884, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 0, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 1, 1], gumbel=-1.921439044094265, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 0, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 1, 1], reward_so_far=-21, status='walking', logprob_so_far=-1.3343675509095192, max_gumbel=-1.921439044094265, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 0, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 1, 2], gumbel=-1.400745251898625, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 0, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 1, 2], reward_so_far=-21, status='walking', logprob_so_far=-1.4691214486956596, max_gumbel=-1.400745251898625, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 0, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 1, 9], gumbel=0.7497922181515688, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 2, 0, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 9, 1, 9], reward_so_far=-21, status='walking', logprob_so_far=-1.1995297595858574, max_gumbel=0.7497922181515688, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 0, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 8, 16], gumbel=-2.7084475297525117, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 0, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 8, 16], reward_so_far=-21, status='walking', logprob_so_far=-1.8177657797932625, max_gumbel=-2.7084475297525117, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 0, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 8, 0], gumbel=-2.567387793770939, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 0, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 8, 0], reward_so_far=-21, status='walking', logprob_so_far=-1.6668528988957405, max_gumbel=-2.567387793770939, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 0, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 8, 9], gumbel=-2.472898154905166, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 0, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 8, 9], reward_so_far=-21, status='walking', logprob_so_far=-1.7616951391100883, max_gumbel=-2.472898154905166, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 0, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 8, 8], gumbel=-1.9423532895479478, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 0, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 8, 8], reward_so_far=-21, status='walking', logprob_so_far=-1.6295474842190742, max_gumbel=-1.9423532895479478, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 1, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 24, 24], gumbel=-2.3232041115170388, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 1, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 24, 24], reward_so_far=-21, status='walking', logprob_so_far=-1.6078633591532707, max_gumbel=-2.3232041115170388, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 1, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 24, 24], gumbel=-2.247560441802954, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 1, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 24, 24], reward_so_far=-21, status='walking', logprob_so_far=-1.4709250554442406, max_gumbel=-2.247560441802954, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 1, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 24, 25], gumbel=-1.7622211358564328, reward=-120, status='failed', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 1, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 24, 25], reward_so_far=-120, status='failed', logprob_so_far=-1.3833179995417595, max_gumbel=-1.7622211358564328, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 1, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 24, 16], gumbel=-1.7037345895848048, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 1, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 24, 16], reward_so_far=-21, status='walking', logprob_so_far=-1.3799248859286308, max_gumbel=-1.7037345895848048, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 3, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 16, 8], gumbel=-1.1241567808387025, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 3, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 16, 8], reward_so_far=-21, status='walking', logprob_so_far=-1.5934886112809181, max_gumbel=-1.1241567808387025, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 3, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 16, 24], gumbel=-0.7535400260448736, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 3, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 16, 24], reward_so_far=-21, status='walking', logprob_so_far=-1.3116614148020744, max_gumbel=-0.7535400260448736, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 3, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 16, 17], gumbel=-0.5945543939131305, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 3, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 16, 17], reward_so_far=-21, status='walking', logprob_so_far=-1.3130332753062248, max_gumbel=-0.5945543939131305, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 3, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 16, 16], gumbel=0.05866530097011846, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 3, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 16, 16], reward_so_far=-21, status='walking', logprob_so_far=-1.2719092890620232, max_gumbel=0.05866530097011846, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 2, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 17, 16], gumbel=-0.1826083556689777, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 2, 3], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 17, 16], reward_so_far=-21, status='walking', logprob_so_far=-1.456493802368641, max_gumbel=-0.1826083556689777, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 2, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 17, 9], gumbel=-0.017284758295044833, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 2, 0], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 17, 9], reward_so_far=-21, status='walking', logprob_so_far=-1.6006819233298302, max_gumbel=-0.017284758295044833, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 2, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 17, 18], gumbel=0.5120781461807337, reward=-21, status='walking', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 2, 2], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 17, 18], reward_so_far=-21, status='walking', logprob_so_far=-1.501146413385868, max_gumbel=0.5120781461807337, next_actions=[0, 1, 2, 3]))
#
# Trajectory(actions=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 2, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 17, 25], gumbel=1.3868366296501455, reward=-120, status='failed', node=Node(prefix=[1, 1, 0, 0, 0, 0, 2, 2, 0, 2, 3, 1, 3, 3, 1, 3, 0, 3, 1, 2, 1], states=[24, 24, 24, 16, 8, 0, 0, 1, 2, 2, 3, 2, 10, 9, 8, 16, 16, 8, 8, 16, 17, 25], reward_so_far=-120, status='failed', logprob_so_far=-1.3063627853989601, max_gumbel=1.3868366296501455, next_actions=[0, 1, 2, 3]))
#
# ['DOWN', 'DOWN', 'UP', 'UP', 'UP', 'UP', 'RIGHT', 'RIGHT', 'UP', 'RIGHT', 'LEFT', 'DOWN', 'LEFT', 'LEFT', 'DOWN', 'LEFT', 'UP', 'LEFT', 'DOWN', 'RIGHT', 'DOWN']

# %% [markdown]
# ## Direct optimization

# %%
def direct_optimization_loss(policy_model,t_opt,t_direct,epsilon=1.0):
    """computes \nabla \phi(a,s) = \sum_{t=1}^T \nabla \phi(a_t, s_t) with direct optimization
    
    Args:
        policy_model: Pytorch model gets state and returns actions logits 
        t_opt: trajectory with the max(gumbel)
        t_direct: trajectory with the max(gumbel+epsilon*reward) 
        epsilon: for direct optimization, usually between 0.9-1.0
    Returns: 
        logits multiplied with vector of (1,0,..,-1) [for example]
        so when we derive it with backward we ends up with \nabla \phi_opt(a,s) - \nabla \phi_direct(a,s)"""
    direct_states  = t_direct.states
    direct_states = torch.LongTensor(direct_states)[:-1].view(-1,1)
    opt_states  = t_opt.states
    opt_states = torch.LongTensor(opt_states)[:-1].view(-1,1)
    
    direct_actions = t_direct.actions
    direct_actions = torch.LongTensor(direct_actions).view(-1,1)
    opt_actions = t_opt.actions    
    opt_actions = torch.LongTensor(opt_actions).view(-1,1)
    
    opt_direct_states = torch.cat((opt_states,direct_states))
    
    phi = policy_model(opt_direct_states) # gets the logits so the network will calculates weights gradients

    #print phi
    y_direct = - torch.FloatTensor(direct_actions.size(0),phi.size(1)).zero_().scatter_(-1,direct_actions,1.0) # one-hot that points to the best direction
    y_opt = torch.FloatTensor(opt_actions.size(0),phi.size(1)).zero_().scatter_(-1, opt_actions,1.0)
    
    y_opt_direct = torch.cat((y_opt,y_direct))
    y_opt_direct = y_opt_direct*(1.0/epsilon)
    
    #print y_opt_direct*phi
    policy_loss = torch.sum(y_opt_direct*phi)   
    return policy_loss

# %% [markdown]
# ## Training

# %%
def get_k_direct_k_star(traj_list,t_direct):
    """
    - Sort trajectories by t_opt (phi+gumbel) and compute how far down t_direct and t* (trajectory with maximum reward) fall on the list.
    Returning these positions k_direct and k*.
    """
    sorted_traj = sorted(traj_list, key=lambda t: t.gumbel)
    t_star = max(traj_list, key=lambda t: t.reward)
    k_direct = sorted_traj.index(t_direct)
    k_star = sorted_traj.index(t_star)
    
    return [(k_direct,k_star),(sorted_traj[k_direct].gumbel,sorted_traj[k_star].gumbel)]

# %%
def run_episode(actions_list):
    """Interacts with the environment given actions """
    rewards = 0
    status = 'walking'
    success = False
    state = env.reset()
    for action in actions_list: 
        state, reward, status = env.step(state,action)
        if status=='succeeded':
            success = True
        rewards += reward
    return rewards,success

# %%
#@timing
def train_policy_model(policy_model, num_episodes=500,section_length=4,epsilon=1.0):

    optimizer = optim.Adam(policy_model.parameters(), lr=0.05)
    success = 0
    rewards = []
    k_direct_star = []
    for episode in range(num_episodes):
        root_node = Node(prefix=[],
               states = [env.reset()],
               reward_so_far=0,
               status='walking',  
               logprob_so_far=0,
               max_gumbel=sample_gumbel(0), 
               next_actions=range(num_actions))
        current_node = root_node
        #policy_loss = 0
        ep_reward = 0
        while  current_node.status not in ['failed','succeeded']:
            #section_length = random.choice(range(3,5))
            t_opt,t_direct,final_trajectories=sample_trajectory_section_gumbels(policy_model=policy_model,
                                                                           init_node = current_node,
                                                                           num_actions=num_actions,
                                                                           section_length=section_length,
                                                                           epsilon=epsilon)
            current_node = t_opt.node  
            policy_loss = direct_optimization_loss(policy_model = policy_model,
                                                   t_opt=t_opt,
                                                   t_direct=t_direct,
                                                   epsilon=epsilon)

            optimizer.zero_grad()
            policy_loss.backward()
            optimizer.step()

        k_direct_star.append(get_k_direct_k_star(final_trajectories,t_direct)) # for visualizations
        trajectory_reward,suc = run_episode(t_opt.actions)
        success += suc

        rewards.append(trajectory_reward)
    return policy_model,success,rewards,k_direct_star

# %%
def episodes_and_steps(min_step,solution_length):
    max_steps = solution_length+1
    #a = [int(1.5**i) for i in range(min_step,max_steps)]
    #a = list(reversed(a))
    #a[0]=120
    a=[100]
    for _ in range(1,max_steps-min_step):
        step = int(a[-1]/2) if int(a[-1]/2) >=10 else 10
        a.append(step)
    #a = [int(i/i) for i in range(1,max_steps-min_step)]
    ep_st = zip(a,range(min_step,solution_length+1))
    print ep_st
    return ep_st

# %%
policy = Policy()

for n_ep,sec_len in episodes_and_steps(min_step=3,solution_length=solution_length):
    policy,num_success,_,k_direct_star = train_policy_model(policy,
                                                            nu m_episodes=n_ep,
                                                            section_length=sec_len,
                                                            epsilon=1.0)
    print num_success,sec_len
num_success # number of times the player has reached the goal
# Out:
# [(100, 3), (50, 4), (25, 5), (12, 6), (10, 7), (10, 8), (10, 9)]
# 57 3
# 42 4
# 24 5
# 12 6
# 10 7
# 10 8
# 9 9
# 9

# %% [markdown]
# ## Visualization

# %%
fig = plt.figure(figsize=(12, 12))
splots = 0
def visualize_k_direct_k_star(k_direct_star_list):
    global splots
    k_tuples,gumbel_tuples = zip(*k_direct_star_list)
    k_direct_list,k_star_list = zip(*k_tuples)
    gumbel_direct_list,gumbel_star_list = zip(*gumbel_tuples)
    
    ax = fig.add_subplot(4,4,splots)
    ax.plot(k_direct_list,'ro',markersize=4)
    ax.plot(k_star_list,'bo',markersize=2)
    ax.title.set_text('epsilon = '+str(eps) +' \n K location')
    splots += 1
    ax = fig.add_subplot(4,4,splots)
    ax.plot(gumbel_direct_list,'ro',markersize=4)
    ax.plot(gumbel_star_list,'bo',markersize=2)
    ax.title.set_text('epsilon = '+str(eps) +' \n Gumbel value')    

epsilons = np.around(np.linspace(0,0.5,8), decimals=2)
epsilons[0]=0.01
for eps in epsilons:
    policy = Policy()
    for n_ep,sec_len in episodes_and_steps(min_step=3,solution_length=solution_length):
        policy,num_success,rewards,k_direct_star = train_policy_model(policy,
                                                                num_episodes=n_ep,
                                                                section_length=sec_len,
                                                                epsilon=eps)

    #policy,num_success,rewards,k_direct_star = train_policy_model(policy,num_episodes=200,epsilon=eps)
    splots += 1
    visualize_k_direct_k_star(k_direct_star)
    
fig.legend(['k_direct','k_star'],loc='center left', bbox_to_anchor=(1, 0.5))
fig.text(0.5, 0, 'Training iterations', ha='center',fontsize=16)
fig.text(0, 0.5, 'Index in sorted phi+gumbel', va='center', rotation='vertical',fontsize=16)
fig.tight_layout()
fig.show()
# Out:
# [(100, 3), (50, 4), (25, 5), (12, 6), (10, 7), (10, 8), (10, 9)]
# [(100, 3), (50, 4), (25, 5), (12, 6), (10, 7), (10, 8), (10, 9)]
# /Users/guy_l/.virtualenvs/pytorch2/lib/python2.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: overflow encountered in exp
# [(100, 3), (50, 4), (25, 5), (12, 6), (10, 7), (10, 8), (10, 9)]
# [(100, 3), (50, 4), (25, 5), (12, 6), (10, 7), (10, 8), (10, 9)]
# [(100, 3), (50, 4), (25, 5), (12, 6), (10, 7), (10, 8), (10, 9)]
# [(100, 3), (50, 4), (25, 5), (12, 6), (10, 7), (10, 8), (10, 9)]
# [(100, 3), (50, 4), (25, 5), (12, 6), (10, 7), (10, 8), (10, 9)]
# [(100, 3), (50, 4), (25, 5), (12, 6), (10, 7), (10, 8), (10, 9)]
# /Users/guy_l/.virtualenvs/pytorch2/lib/python2.7/site-packages/matplotlib/figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
trials = 5
all_rewards =[]
for trial in range(trials):
    policy = Policy()
    tr_rewards = []
    #for n_ep,sec_len in episodes_and_steps(min_step=3,solution_length=solution_length):    
    for n_ep,sec_len in episodes_and_steps(min_step=3,solution_length=solution_length):
        policy,num_success,rewards,_ = train_policy_model(policy,
                                                        num_episodes=n_ep,
                                                        section_length=sec_len,
                                                        epsilon=eps)
        #print rewards
        tr_rewards += rewards
    all_rewards.append(tr_rewards)
avg_rewards = np.mean(all_rewards, axis=0)

mean_reward = [np.mean(avg_rewards)] * len(avg_rewards)
fig, ax = plt.subplots()
ax.set_xlabel('Episodes')
ax.set_ylabel('Rewards')
ax.plot(avg_rewards)
ax.plot(mean_reward, 'g--')

print('Mean Reward: {}'.format(mean_reward[0]))
# Out:
# [(100, 3), (50, 4), (25, 5), (12, 6), (10, 7), (10, 8), (10, 9)]
# [(100, 3), (50, 4), (25, 5), (12, 6), (10, 7), (10, 8), (10, 9)]
# [(100, 3), (50, 4), (25, 5), (12, 6), (10, 7), (10, 8), (10, 9)]
# [(100, 3), (50, 4), (25, 5), (12, 6), (10, 7), (10, 8), (10, 9)]
# [(100, 3), (50, 4), (25, 5), (12, 6), (10, 7), (10, 8), (10, 9)]
# Mean Reward: 9.19078341014

# %%
def fill_q_values(policy):
    q_values_pg = np.zeros((num_states, num_actions))

    for s in range(num_states):
        state = torch.LongTensor([s]).unsqueeze(0)
        q_values_pg[s] = F.softmax(policy(state),dim=-1).detach().numpy()
    return q_values_pg

# %%
def play(policy,section_length):
    
    env = GridWorld()
    state = env.reset()
    t_opt,t_direct,_ = sample_full_trajectory_gumbels(policy,num_actions,section_length=section_length,epsilon=1.0)
    actions = t_opt.actions
    print [ACTIONS[actions[i]] for i in range(len(actions))]
    
    status = 'walking'
    history = [state]
    for action in actions:    
        # Select action
        # Do the action
        state, reward, status = env.step(state,action)
        history.append(state)

        env.player = env._id_to_position(state)
        #raw_input("Press Enter to continue...")
        env.render(q_values= fill_q_values(policy),history=history, colorize_q=True)
        #raw_input("Press Enter to continue...")
        if status == 'succeeded':
            return
    print 'path not found'

# %%
play(policy=policy,section_length=5)
# Out:
# ['UP', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'RIGHT', 'DOWN']
